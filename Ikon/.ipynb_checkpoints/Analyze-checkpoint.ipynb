# %%
import pandas as pd

# %%
from CRUD import *
connection = connectToDatabase("../resources/ikon.db")
artists = select_artists(connection)

# %%
df = pd.DataFrame(artists)
df
# Out:
#            0                                 1
# 0       6792                     - szociológus
# 1       5431                   A. E. Bizottság
# 2      10436                 A. Gergely András
# 3       6711              A. Petényi Zsuzsanna
# 4       8411                    A. TÓTH Sándor
# 5       4442                    A. Tóth József
# 6       9006                    A. Ádám József
# 7      11332                    A.P.A. Galéria
# 8      11051                   AART ARCHITECTS
# 9      10130                     AATOTH franyo
# 10      7496                  ABA-NOVÁK Vilmos
# 11     14984                     ADRIAN GHENIE
# 12     11824                       ADRIAN PACI
# 13     16179                    AGNIESZKA RAYS
# 14      9239                     AKNAI KATALIN
# 15     11816                    ALBAN HAJDINAJ
# 16     11836                        ALBAN MUJA
# 17     14569                    ALBERT Alianna
# 18      2574                       ALBERT Ádám
# 19     10559                    ALBRECHT JÚLIA
# 20      7497                      ALEXY Károly
# 21     12877                 ALMÁSSY Krisztián
# 22      7498                   ALTORJAI Sándor
# 23     15763                    ALTORJAY Gábor
# 24      9019                     AMANDA DJ SET
# 25      7344                         ANA VENUS
# 26     11994                        ANCA BODEA
# 27     16390               ANDREJKOVICS ZOLTÁN
# 28     10622                       ANDRÁS Edit
# 29      9899                     ANDRÁS Sándor
# ...      ...                               ...
# 11409  14827                        Ördög Nóra
# 11410  11914                         Öreg Nóra
# 11411   5524                     Örkényi Antal
# 11412   9041           Örkényi Strasser István
# 11413  13647                      Örményi Ákos
# 11414   1869                      Ötvös Zoltán
# 11415   8999            Újgenerációs Valóságok
# 11416   4337                      Újházi János
# 11417   4121                      Újházi Péter
# 11418   1237                         Újirány C
# 11419  11247                    Újszászi Tünde
# 11420  15653         Újvárossy Kerekes Gyöngyi
# 11421   6129                         Ütő Endre
# 11422   3771                       Ütő Gusztáv
# 11423   4408                      Üveges Gábor
# 11424   7570                  Üveges Krisztina
# 11425  11456                     Üveges Mónika
# 11426   6244                      Üveges Péter
# 11427   6968                      Üveges Tamás
# 11428   1903        Üzenet Marshall McLuhannak
# 11429  10989                        új rektora
# 11430   5629  ŐEXCELLENCIÁJA ROLAND GALHARAGUE
# 11431   5087           Őexcellenciája Ilan Mor
# 11432  17487                     Őry Annamária
# 11433  15674                        Őry Eszter
# 11434    563                         Ősz Gábor
# 11435   9013                 Ősz-Varga Szabina
# 11436   8923                    Őszi fesztivál
# 11437   5473                        Őze Eszter
# 11438   4676                          Őze Áron
#
# [11439 rows x 2 columns]

# %%
connection.execute("SELECT Count(*) FROM artists").fetchone()[0]
# Out:
# 11439

# %% [markdown]
# # Analyze

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
# exhibition distribution amoung artists
sql = '''
SELECT COUNT(ae.artist_id) as c
FROM artists_exhibitions ae
JOIN artists a ON a.id = ae.artist_id
GROUP BY ae.artist_id
ORDER BY c DESC;
'''

counts = [r[0] for r in connection.execute(sql).fetchall()]

plt.bar(list(range(len(counts))), counts)
# Out:
# <BarContainer object of 11439 artists>

# %%
# exhibitions distribution amoung weekdays
sql = '''
SELECT COUNT(*), strftime("%w", date)
FROM exhibitions
GROUP BY strftime("%w", date)
'''

counts = [r[0] for r in connection.execute(sql).fetchall()]
plt.bar(["Sunday","Monday","Tuesday","Wednesday","Thurday","Friday","Saturday"], counts)
# Out:
# <BarContainer object of 7 artists>
